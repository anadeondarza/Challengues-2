# %%
import pandas as pd
import numpy as np

# %%
df_movies = pd.read_csv('/Users/anadeondarza/Desktop/ironhack_data/challenges/Proyecto final/movies_final.csv')

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15981 entries, 0 to 15980
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.2  15981 non-null  int64
#  1   Unnamed: 0.1  15981 non-null  int64
#  2   Unnamed: 0    15981 non-null  int64
#  3   show_id       15981 non-null  object
#  4   type          15981 non-null  object
#  5   title         15981 non-null  object
#  6   director      14123 non-null  object
#  7   cast          13262 non-null  object
#  8   country       7422 non-null   object
#  9   release_year  15981 non-null  int64
#  10  duration      15537 non-null  object
#  11  listed_in     15981 non-null  object
#  12  description   15978 non-null  object
#  13  description_  15978 non-null  object
#  14  all           15981 non-null  object
#  15  sentiment     15981 non-null  object
# dtypes: int64(4), object(12)
# memory usage: 2.0+ MB

# %%
df_movies['release_year'] = df_movies['release_year'].astype('str')

# %%
df_movies
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 show_id   type  \
# 0                 0             0           0      s1  Movie
# 1                 1             1           1      s7  Movie
# 2                 2             2           2      s8  Movie
# 3                 3             3           3     s10  Movie
# 4                 4             4           4     s13  Movie
# ...             ...           ...         ...     ...    ...
# 15976         15976         15976       15976   s9661  Movie
# 15977         15977         15977       15977   s9663  Movie
# 15978         15978         15978       15978   s9664  Movie
# 15979         15979         15979       15979   s9666  Movie
# 15980         15980         15980       15980   s9668  Movie
#
#                                   title                             director  \
# 0                  Dick Johnson Is Dead                      Kirsten Johnson
# 1      My Little Pony: A New Generation        Robert Cullen, José Luis Ucha
# 2                               Sankofa                         Haile Gerima
# 3                          The Starling                       Theodore Melfi
# 4                          Je Suis Karl                  Christian Schwochow
# ...                                 ...                                  ...
# 15976                The Man in the Hat  John-Paul Davidson, Stephen Warbeck
# 15977                             River                           Emily Skye
# 15978               Pride Of The Bowery                      Joseph H. Lewis
# 15979                           Outpost                         Steve Barker
# 15980                       Harry Brown                        Daniel Barber
#
#                                                     cast  \
# 0                                                    NaN
# 1      Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 2      Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 3      Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 4      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                  ...
# 15976             Ciaran Hinds, Stephen Dillane, Maïwenn
# 15977  Mary Cameron Rogers, Alexandra Rose, Rob Marsh...
# 15978                           Leo Gorcey, Bobby Jordan
# 15979  Ray Stevenson, Julian Wadham, Richard Brake, M...
# 15980  Michael Caine, Emily Mortimer, Joseph Gilgun, ...
#
#                                                  country release_year  \
# 0                                          United States         2020
# 1                                                    NaN         2021
# 2      United States, Ghana, Burkina Faso, United Kin...         1993
# 3                                          United States         2021
# 4                                Germany, Czech Republic         2021
# ...                                                  ...          ...
# 15976                                                NaN         2021
# 15977                                                NaN         2021
# 15978                                                NaN         1940
# 15979                                                NaN         2008
# 15980                                                NaN         2010
#
#       duration                                         listed_in  \
# 0       90 min                                     Documentaries
# 1       91 min                          Children & Family Movies
# 2      125 min  Dramas, Independent Movies, International Movies
# 3      104 min                                  Comedies, Dramas
# 4      127 min                      Dramas, International Movies
# ...        ...                                               ...
# 15976   96 min                                            Comedy
# 15977   93 min                  Drama, Science Fiction, Suspense
# 15978   60 min                                            Comedy
# 15979   90 min                                            Action
# 15980  103 min                           Action, Drama, Suspense
#
#                                              description  \
# 0      As her father nears the end of his life, filmm...
# 1      Equestria's divided. But a bright-eyed hero be...
# 2      On a photo shoot in Ghana, an American model s...
# 3      A woman adjusting to life after a loss contend...
# 4      After most of her family is murdered in a terr...
# ...                                                  ...
# 15976  The Man in the Hat journeys through France in ...
# 15977  River is a grounded Sci-Fi mystery Thriller, t...
# 15978  New York City street principles get an East Si...
# 15979  In war-torn Eastern Europe, a world-weary grou...
# 15980  Harry Brown, starring two-time Academy Award w...
#
#                                             description_  \
# 0      as her father nears the end of his life, filmm...
# 1      equestria's divided. but a bright-eyed hero be...
# 2      on a photo shoot in ghana, an american model s...
# 3      a woman adjusting to life after a loss contend...
# 4      after most of her family is murdered in a terr...
# ...                                                  ...
# 15976  the man in the hat journeys through france in ...
# 15977  river is a grounded sci-fi mystery thriller, t...
# 15978  new york city street principles get an east si...
# 15979  in war-torn eastern europe, a world-weary grou...
# 15980  harry brown, starring two-time academy award w...
#
#                                                      all sentiment
# 0      MovieDick Johnson Is DeadKirsten JohnsonnanUni...  POSITIVE
# 1      MovieMy Little Pony: A New GenerationRobert Cu...  POSITIVE
# 2      MovieSankofaHaile GerimaKofi Ghanaba, Oyafunmi...  POSITIVE
# 3      MovieThe StarlingTheodore MelfiMelissa McCarth...  POSITIVE
# 4      MovieJe Suis KarlChristian SchwochowLuna Wedle...  NEGATIVE
# ...                                                  ...       ...
# 15976  MovieThe Man in the HatJohn-Paul Davidson, Ste...  NEGATIVE
# 15977  MovieRiverEmily SkyeMary Cameron Rogers, Alexa...  POSITIVE
# 15978  MoviePride Of The BoweryJoseph H. LewisLeo Gor...  NEGATIVE
# 15979  MovieOutpostSteve BarkerRay Stevenson, Julian ...  POSITIVE
# 15980  MovieHarry BrownDaniel BarberMichael Caine, Em...  POSITIVE
#
# [15981 rows x 16 columns]

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15981 entries, 0 to 15980
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.2  15981 non-null  int64
#  1   Unnamed: 0.1  15981 non-null  int64
#  2   Unnamed: 0    15981 non-null  int64
#  3   show_id       15981 non-null  object
#  4   type          15981 non-null  object
#  5   title         15981 non-null  object
#  6   director      14123 non-null  object
#  7   cast          13262 non-null  object
#  8   country       7422 non-null   object
#  9   release_year  15981 non-null  object
#  10  duration      15537 non-null  object
#  11  listed_in     15981 non-null  object
#  12  description   15978 non-null  object
#  13  description_  15978 non-null  object
#  14  all           15981 non-null  object
#  15  sentiment     15981 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 2.0+ MB

# %%
import sqlalchemy
from sqlalchemy import create_engine

# %%
DB_SQLITE = 'file_db.db' ##Nombre de como se llamará tu archivo .db

# %%
# create table from df
def to_sql_k(self, frame, name, if_exists='fail', 
             index=False, index_label=None, schema=None, 
             chunksize=None, dtype=None, **kwargs):
    if dtype is not None:
        from sqlalchemy.types import to_instance, TypeEngine
        for col, my_type in dtype.items():
            if not isinstance(to_instance(my_type), TypeEngine):
                raise ValueError('The type of %s is not a SQLAlchemy '
                                 'type ' % col)

    table = pd.io.sql.SQLTable(name, self, frame=frame, index=index,
                               if_exists=if_exists, index_label=index_label,
                               schema=schema, dtype=dtype, **kwargs)
    table.create()
    table.insert(chunksize)

# %%
# create table sqlite
def to_sqlite(df, name_table):
    engine = create_engine(f'sqlite:///{DB_SQLITE}')
    pandas_sql = pd.io.sql.pandasSQL_builder(engine, schema=None)

    to_sql_k(pandas_sql, frame=df, name=name_table)

# %%
to_sqlite(df_movies, 'movies') ### se llama a la función para crear la tabla people en la bbdd con el contenido del df
