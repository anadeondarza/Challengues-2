# %%
import pandas as pd
import numpy as np

# %%
df_netflix = pd.read_csv('/Users/anadeondarza/Desktop/ironhack_data/challenges/Proyecto final/netflix_titles.csv')

# %%
df_disney = pd.read_csv('/Users/anadeondarza/Desktop/ironhack_data/challenges/Proyecto final/disney_plus_titles.csv')

# %%
df_amazon = pd.read_csv('/Users/anadeondarza/Desktop/ironhack_data/challenges/Proyecto final/amazon_prime_titles.csv')

# %%
df_hulu = pd.read_csv('/Users/anadeondarza/Desktop/ironhack_data/challenges/Proyecto final/hulu_titles.csv')

# %% [markdown]
# ### Netflix

# %%
df_netflix.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df_quitado = df_netflix.drop(['rating', 'date_added'], axis=1)

# %%
df_netflix_movies = df_quitado[df_quitado.type == 'Movie']

# %%
df_netflix_tvshow = df_quitado[df_quitado.type == 'TV Show']

# %% [markdown]
# ### Disney

# %%
df_disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1450 entries, 0 to 1449
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1450 non-null   object
#  1   type          1450 non-null   object
#  2   title         1450 non-null   object
#  3   director      977 non-null    object
#  4   cast          1260 non-null   object
#  5   country       1231 non-null   object
#  6   date_added    1447 non-null   object
#  7   release_year  1450 non-null   int64
#  8   rating        1447 non-null   object
#  9   duration      1450 non-null   object
#  10  listed_in     1450 non-null   object
#  11  description   1450 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 136.1+ KB

# %%
dfD_quitado = df_disney.drop(['rating', 'date_added'], axis=1)

# %%
df_disney_movies = dfD_quitado[dfD_quitado.type == 'Movie']

# %%
df_disney_tvshow = dfD_quitado[dfD_quitado.type == 'TV Show']

# %% [markdown]
# ### Amazon

# %%
df_amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9668 entries, 0 to 9667
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       9668 non-null   object
#  1   type          9668 non-null   object
#  2   title         9668 non-null   object
#  3   director      7586 non-null   object
#  4   cast          8435 non-null   object
#  5   country       672 non-null    object
#  6   date_added    155 non-null    object
#  7   release_year  9668 non-null   int64
#  8   rating        9331 non-null   object
#  9   duration      9668 non-null   object
#  10  listed_in     9668 non-null   object
#  11  description   9668 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 906.5+ KB

# %%
df_amazon.describe()
# Out:
#        release_year
# count   9668.000000
# mean    2008.341849
# std       18.922482
# min     1920.000000
# 25%     2007.000000
# 50%     2016.000000
# 75%     2019.000000
# max     2021.000000

# %%
dfA_quitado = df_amazon.drop(['rating', 'date_added'], axis=1)

# %%
df_amazon_movies = dfA_quitado[dfA_quitado.type == 'Movie']

# %%
df_amazon_tvshow = dfA_quitado[dfA_quitado.type == 'TV Show']

# %% [markdown]
# ### Hulu

# %%
df_hulu.describe()
# Out:
#        cast  release_year
# count   0.0   3073.000000
# mean    NaN   2012.567524
# std     NaN     10.844069
# min     NaN   1923.000000
# 25%     NaN   2010.000000
# 50%     NaN   2016.000000
# 75%     NaN   2019.000000
# max     NaN   2021.000000

# %%
df_hulu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3073 entries, 0 to 3072
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       3073 non-null   object
#  1   type          3073 non-null   object
#  2   title         3073 non-null   object
#  3   director      3 non-null      object
#  4   cast          0 non-null      float64
#  5   country       1620 non-null   object
#  6   date_added    3045 non-null   object
#  7   release_year  3073 non-null   int64
#  8   rating        2553 non-null   object
#  9   duration      2594 non-null   object
#  10  listed_in     3073 non-null   object
#  11  description   3069 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 288.2+ KB

# %%
dfH_quitado = df_hulu.drop(['rating', 'date_added'], axis=1)

# %%
df_hulu_movies = dfH_quitado[dfH_quitado.type == 'Movie']

# %%
df_hulu_tvshow = dfH_quitado[dfH_quitado.type == 'TV Show']

# %% [markdown]
# ### Movies

# %%
df_netflix_movies.reset_index(drop=True)
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 1         s7  Movie  My Little Pony: A New Generation
# 2         s8  Movie                           Sankofa
# 3        s10  Movie                      The Starling
# 4        s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 6126   s8802  Movie                           Zinzana
# 6127   s8803  Movie                            Zodiac
# 6128   s8805  Movie                        Zombieland
# 6129   s8806  Movie                              Zoom
# 6130   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 1     Robert Cullen, José Luis Ucha
# 2                      Haile Gerima
# 3                    Theodore Melfi
# 4               Christian Schwochow
# ...                             ...
# 6126                Majid Al Ansari
# ...

# %%
df_hulu_movies.reset_index(drop=True)
# Out:
#      show_id   type                                      title director  cast  \
# 0         s1  Movie             Ricky Velez: Here's Everything      NaN   NaN
# 1         s2  Movie                               Silent Night      NaN   NaN
# 2         s3  Movie                               The Marksman      NaN   NaN
# 3         s4  Movie                                       Gaia      NaN   NaN
# 4         s5  Movie                                   Settlers      NaN   NaN
# ...      ...    ...                                        ...      ...   ...
# 1479   s2956  Movie                                 Getting On      NaN   NaN
# 1480   s2959  Movie                         (Sub) Ninja Scroll      NaN   NaN
# 1481   s2960  Movie                      Packed to the Rafters      NaN   NaN
# 1482   s2983  Movie  (Sub) Legend of Heroes: Trails in the Sky      NaN   NaN
# 1483   s2994  Movie             Amy Winehouse: A Final Goodbye      NaN   NaN
#
# ...

# %%
df_disney_movies
# Out:
#      show_id   type                                             title  \
# 0         s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2  Movie                            Ernest Saves Christmas
# 2         s3  Movie                      Ice Age: A Mammoth Christmas
# 3         s4  Movie                        The Queen Family Singalong
# 5         s6  Movie                                 Becoming Cousteau
# ...      ...    ...                                               ...
# 1445   s1446  Movie                          X-Men Origins: Wolverine
# 1446   s1447  Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448  Movie                                   Eddie the Eagle
# 1448   s1449  Movie                              Bend It Like Beckham
# 1449   s1450  Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# 1                           John Cherry
# ...

# %%
df_amazon_movies.reset_index(drop=True)
# Out:
#      show_id   type                 title  \
# 0         s1  Movie   The Grand Seduction
# 1         s2  Movie  Take Care Good Night
# 2         s3  Movie  Secrets of Deception
# 3         s4  Movie    Pink: Staying True
# 4         s5  Movie         Monster Maker
# ...      ...    ...                   ...
# 7809   s9661  Movie    The Man in the Hat
# 7810   s9663  Movie                 River
# 7811   s9664  Movie   Pride Of The Bowery
# 7812   s9666  Movie               Outpost
# 7813   s9668  Movie           Harry Brown
#
#                                  director  \
# 0                            Don McKellar
# 1                            Girish Joshi
# 2                             Josh Webber
# 3                          Sonia Anderson
# 4                            Giles Foster
# ...                                   ...
# 7809  John-Paul Davidson, Stephen Warbeck
# 7810                           Emily Skye
# 7811                      Joseph H. Lewis
# ...

# %%
df_movies = pd.concat([df_netflix_movies,df_hulu_movies,df_disney_movies,df_amazon_movies])

# %%
df_movies.reset_index(drop=True)
# Out:
#       show_id   type                             title  \
# 0          s1  Movie              Dick Johnson Is Dead
# 1          s7  Movie  My Little Pony: A New Generation
# 2          s8  Movie                           Sankofa
# 3         s10  Movie                      The Starling
# 4         s13  Movie                      Je Suis Karl
# ...       ...    ...                               ...
# 16476   s9661  Movie                The Man in the Hat
# 16477   s9663  Movie                             River
# 16478   s9664  Movie               Pride Of The Bowery
# 16479   s9666  Movie                           Outpost
# 16480   s9668  Movie                       Harry Brown
#
#                                   director  \
# 0                          Kirsten Johnson
# 1            Robert Cullen, José Luis Ucha
# 2                             Haile Gerima
# 3                           Theodore Melfi
# 4                      Christian Schwochow
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16481 entries, 0 to 9667
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16481 non-null  object
#  1   type          16481 non-null  object
#  2   title         16481 non-null  object
#  3   director      14509 non-null  object
#  4   cast          13639 non-null  object
#  5   country       7867 non-null   object
#  6   release_year  16481 non-null  int64
#  7   duration      15999 non-null  object
#  8   listed_in     16481 non-null  object
#  9   description   16478 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.4+ MB

# %%
df_movies.describe()
# Out:
#        release_year
# count  16481.000000
# mean    2009.224562
# std       17.168334
# min     1920.000000
# 25%     2008.000000
# 50%     2016.000000
# 75%     2019.000000
# max     2021.000000

# %%
movies = df_movies.drop_duplicates(['title'], keep='last')

# %%
movies = movies.reset_index(drop=True)

# %%
movies
# Out:
#       show_id   type                             title  \
# 0          s1  Movie              Dick Johnson Is Dead
# 1          s7  Movie  My Little Pony: A New Generation
# 2          s8  Movie                           Sankofa
# 3         s10  Movie                      The Starling
# 4         s13  Movie                      Je Suis Karl
# ...       ...    ...                               ...
# 15976   s9661  Movie                The Man in the Hat
# 15977   s9663  Movie                             River
# 15978   s9664  Movie               Pride Of The Bowery
# 15979   s9666  Movie                           Outpost
# 15980   s9668  Movie                       Harry Brown
#
#                                   director  \
# 0                          Kirsten Johnson
# 1            Robert Cullen, José Luis Ucha
# 2                             Haile Gerima
# 3                           Theodore Melfi
# 4                      Christian Schwochow
# ...

# %%
#movies['description'] = movies['description'].apply(lambda _: str(_))

# %%
movies['description'] = movies['description'].values.astype(str)

# %%
def string_transformer(x):
    return x.strip().lower().replace("!#$%^&*()",' ')

# %%
string_transformer('sksKksks ')
# Out:
# 'skskksks'

# %%
movies['description_'] = movies['description'].apply(string_transformer)

#replace caracteres especiales con espacios

# %%
#movies["description"]= movies["description"].values.astype(str)

# %%
#def processString(txt): 
   # return txt.replace("!#$%^&*()",' ')

# %%
#movies['description_'] = movies['description'].apply(processString)

# %%
str in movies.description.values
# Out:
# False

# %%
"""for i in movies['description']:
    if i is not str:
        print(type(i))"""


[type(i) for i in x if ]
# Out:
# "for i in movies['description']:\n    if i is not str:\n        print(type(i))"

# %%
#y = [i for i in movies['description'] if i is not str]

# %%
len(lista)
# Out:
# 15981

# %%
set(lista)
# Out:
# {str}

# %%
"""for i in movies['description']:
    if 
        print(i)"""
# Out:
# "for i in movies['description']:\n    if \n        print(i)"

# %%
#movies['description'] = [eliminar(movies) for i in movies['description']]

# %%
#movies = movies.dropna(subset=["description"])
#movies

# %%
movies
# Out:
#       show_id   type                             title  \
# 0          s1  Movie              Dick Johnson Is Dead
# 1          s7  Movie  My Little Pony: A New Generation
# 2          s8  Movie                           Sankofa
# 3         s10  Movie                      The Starling
# 4         s13  Movie                      Je Suis Karl
# ...       ...    ...                               ...
# 15976   s9661  Movie                The Man in the Hat
# 15977   s9663  Movie                             River
# 15978   s9664  Movie               Pride Of The Bowery
# 15979   s9666  Movie                           Outpost
# 15980   s9668  Movie                       Harry Brown
#
#                                   director  \
# 0                          Kirsten Johnson
# 1            Robert Cullen, José Luis Ucha
# 2                             Haile Gerima
# 3                           Theodore Melfi
# 4                      Christian Schwochow
# ...

# %%
movies["all"] = movies["type"].astype(str) + movies["title"].astype(str) + movies["director"].astype(str) + movies["cast"].astype(str) + movies["country"].astype(str) + movies["listed_in"].astype(str) + movies["description_"].astype(str)

# %%
movies
# Out:
#       show_id   type                             title  \
# 0          s1  Movie              Dick Johnson Is Dead
# 1          s7  Movie  My Little Pony: A New Generation
# 2          s8  Movie                           Sankofa
# 3         s10  Movie                      The Starling
# 4         s13  Movie                      Je Suis Karl
# ...       ...    ...                               ...
# 15976   s9661  Movie                The Man in the Hat
# 15977   s9663  Movie                             River
# 15978   s9664  Movie               Pride Of The Bowery
# 15979   s9666  Movie                           Outpost
# 15980   s9668  Movie                       Harry Brown
#
#                                   director  \
# 0                          Kirsten Johnson
# 1            Robert Cullen, José Luis Ucha
# 2                             Haile Gerima
# 3                           Theodore Melfi
# 4                      Christian Schwochow
# ...

# %%
movies.to_csv('movies_all.csv')

# %% [markdown]
# ### TV Show

# %%
df_hulu_tvshow.reset_index(drop=True)
# Out:
#      show_id     type                                              title  \
# 0         s6  TV Show                      The Halloween Candy Magic Pet
# 1         s8  TV Show                             The Next Thing You Eat
# 2         s9  TV Show                                             Queens
# 3        s10  TV Show                                   The Bachelorette
# 4        s11  TV Show  The Real Queens of Hip-Hop: The Women Who Chan...
# ...      ...      ...                                                ...
# 1584   s3069  TV Show                     Star Trek: The Original Series
# 1585   s3070  TV Show                                 Star Trek: Voyager
# 1586   s3071  TV Show                                          The Fades
# 1587   s3072  TV Show                                  The Twilight Zone
# 1588   s3073  TV Show                                Tokyo Magnitude 8.0
#
#      director  cast         country  release_year   duration  \
# ...

# %%
df_netflix_tvshow.reset_index(drop=True)
# Out:
#      show_id     type                  title         director  \
# 0         s2  TV Show          Blood & Water              NaN
# 1         s3  TV Show              Ganglands  Julien Leclercq
# 2         s4  TV Show  Jailbirds New Orleans              NaN
# 3         s5  TV Show           Kota Factory              NaN
# 4         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 2671   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 2672   s8797  TV Show             Yunus Emre              NaN
# 2673   s8798  TV Show              Zak Storm              NaN
# 2674   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 2675   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 0     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 1     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
df_disney_tvshow.reset_index(drop=True)
# Out:
#     show_id     type                      title director  \
# 0        s5  TV Show      The Beatles: Get Back      NaN
# 1        s7  TV Show                    Hawkeye      NaN
# 2        s8  TV Show     Port Protection Alaska      NaN
# 3        s9  TV Show  Secrets of the Zoo: Tampa      NaN
# 4       s14  TV Show      Dr. Oakley, Yukon Vet      NaN
# ..      ...      ...                        ...      ...
# 393   s1418  TV Show           X-Men: Evolution      NaN
# 394   s1435  TV Show                  Smart Guy      NaN
# 395   s1440  TV Show       Disney Kirby Buckets      NaN
# 396   s1441  TV Show             Disney Mech-X4      NaN
# 397   s1442  TV Show         Imagination Movers      NaN
#
#                                                   cast        country  \
# 0    John Lennon, Paul McCartney, George Harrison, ...            NaN
# 1    Jeremy Renner, Hailee Steinfeld, Vera Farmiga,...            NaN
# ...

# %%
df_amazon_tvshow.reset_index(drop=True)
# Out:
#      show_id     type                          title director  \
# 0        s18  TV Show                     Zoo Babies      NaN
# 1        s19  TV Show  Zoë Coombs Marr: Bossy Bottom      NaN
# 2        s21  TV Show                     Zoboomafoo      NaN
# 3        s22  TV Show      Zo Zo Zombie: Mini-Series      NaN
# 4        s24  TV Show                   ZeroZeroZero      NaN
# ...      ...      ...                            ...      ...
# 1849   s9652  TV Show                     Glass Room      NaN
# 1850   s9656  TV Show          DaFUNdamentals Series      NaN
# 1851   s9662  TV Show                     Terrahawks      NaN
# 1852   s9665  TV Show                  Planet Patrol      NaN
# 1853   s9667  TV Show        Maradona: Blessed Dream      NaN
#
#                                                    cast country  release_year  \
# 0                            Narrator - Gillian Barlett     NaN          2008
# ...

# %%
df_tvshow = pd.concat([df_hulu_tvshow,df_netflix_tvshow,df_disney_tvshow,df_amazon_tvshow])

# %%
df_tvshow.reset_index(drop=True)
# Out:
#      show_id     type                                              title  \
# 0         s6  TV Show                      The Halloween Candy Magic Pet
# 1         s8  TV Show                             The Next Thing You Eat
# 2         s9  TV Show                                             Queens
# 3        s10  TV Show                                   The Bachelorette
# 4        s11  TV Show  The Real Queens of Hip-Hop: The Women Who Chan...
# ...      ...      ...                                                ...
# 6512   s9652  TV Show                                         Glass Room
# 6513   s9656  TV Show                              DaFUNdamentals Series
# 6514   s9662  TV Show                                         Terrahawks
# 6515   s9665  TV Show                                      Planet Patrol
# 6516   s9667  TV Show                            Maradona: Blessed Dream
#
#      director                                               cast  \
# ...

# %%
TV_shows = df_tvshow.drop_duplicates(['title'], keep='last')

# %%
TV_shows.reset_index(drop=True)
# Out:
#      show_id     type                                              title  \
# 0         s6  TV Show                      The Halloween Candy Magic Pet
# 1         s8  TV Show                             The Next Thing You Eat
# 2         s9  TV Show                                             Queens
# 3        s11  TV Show  The Real Queens of Hip-Hop: The Women Who Chan...
# 4        s14  TV Show                                          Wakefield
# ...      ...      ...                                                ...
# 6256   s9652  TV Show                                         Glass Room
# 6257   s9656  TV Show                              DaFUNdamentals Series
# 6258   s9662  TV Show                                         Terrahawks
# 6259   s9665  TV Show                                      Planet Patrol
# 6260   s9667  TV Show                            Maradona: Blessed Dream
#
#      director                                               cast country  \
# ...

# %%
TV_shows.drop([711, 8708, 8726, 8727, 8728, 8752,8753, 8759, 8760, 8761, 8762,8763, 8764],axis=0)
# Out:
#      show_id     type                                              title  \
# 5         s6  TV Show                      The Halloween Candy Magic Pet
# 7         s8  TV Show                             The Next Thing You Eat
# 8         s9  TV Show                                             Queens
# 10       s11  TV Show  The Real Queens of Hip-Hop: The Women Who Chan...
# 13       s14  TV Show                                          Wakefield
# ...      ...      ...                                                ...
# 9651   s9652  TV Show                                         Glass Room
# 9655   s9656  TV Show                              DaFUNdamentals Series
# 9661   s9662  TV Show                                         Terrahawks
# 9664   s9665  TV Show                                      Planet Patrol
# 9666   s9667  TV Show                            Maradona: Blessed Dream
#
#      director                                               cast country  \
# ...

# %%
str in TV_shows.description.values
# Out:
# False

# %%
TV_shows['description'] = TV_shows['description'].values.astype(str)
# Out:
# /var/folders/nr/c9s62s617y19j9y8cd0wk75c0000gn/T/ipykernel_25548/3919054299.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TV_shows['description'] = TV_shows['description'].values.astype(str)

# %%
TV_shows['description_'] = TV_shows['description'].apply(string_transformer)
# Out:
# /var/folders/nr/c9s62s617y19j9y8cd0wk75c0000gn/T/ipykernel_25548/524192843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TV_shows['description_'] = TV_shows['description'].apply(string_transformer)

# %%
TV_shows
# Out:
#      show_id     type                                              title  \
# 5         s6  TV Show                      The Halloween Candy Magic Pet
# 7         s8  TV Show                             The Next Thing You Eat
# 8         s9  TV Show                                             Queens
# 10       s11  TV Show  The Real Queens of Hip-Hop: The Women Who Chan...
# 13       s14  TV Show                                          Wakefield
# ...      ...      ...                                                ...
# 9651   s9652  TV Show                                         Glass Room
# 9655   s9656  TV Show                              DaFUNdamentals Series
# 9661   s9662  TV Show                                         Terrahawks
# 9664   s9665  TV Show                                      Planet Patrol
# 9666   s9667  TV Show                            Maradona: Blessed Dream
#
#      director                                               cast country  \
# ...

# %%
TV_shows["all"] = TV_shows["type"].astype(str) + TV_shows["title"].astype(str) + TV_shows["director"].astype(str) + TV_shows["cast"].astype(str) + TV_shows["country"].astype(str) + TV_shows["listed_in"].astype(str) + TV_shows["description"].astype(str)
# Out:
# /var/folders/nr/c9s62s617y19j9y8cd0wk75c0000gn/T/ipykernel_25548/3816316269.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   TV_shows["all"] = TV_shows["type"].astype(str) + TV_shows["title"].astype(str) + TV_shows["director"].astype(str) + TV_shows["cast"].astype(str) + TV_shows["country"].astype(str) + TV_shows["listed_in"].astype(str) + TV_shows["description"].astype(str)

# %%
TV_shows.to_csv('tv_shows_all.csv')

# %% [markdown]
# ###Movies

# %%
movies = pd.read_csv('/Users/anadeondarza/Desktop/ironhack_data/challenges/Proyecto final/emovies_final.csv')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15981 entries, 0 to 15980
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  15981 non-null  int64
#  1   Unnamed: 0    15981 non-null  int64
#  2   show_id       15981 non-null  object
#  3   type          15981 non-null  object
#  4   title         15981 non-null  object
#  5   director      14123 non-null  object
#  6   cast          13262 non-null  object
#  7   country       7422 non-null   object
#  8   release_year  15981 non-null  int64
#  9   duration      15537 non-null  object
#  10  listed_in     15981 non-null  object
#  11  description   15978 non-null  object
#  12  description_  15978 non-null  object
#  13  all           15981 non-null  object
#  14  sentiment     15981 non-null  object
# dtypes: int64(3), object(12)
# memory usage: 1.8+ MB

# %%
movies['release_year'] = movies['release_year'].values.astype(str)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15981 entries, 0 to 15980
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  15981 non-null  int64
#  1   Unnamed: 0    15981 non-null  int64
#  2   show_id       15981 non-null  object
#  3   type          15981 non-null  object
#  4   title         15981 non-null  object
#  5   director      14123 non-null  object
#  6   cast          13262 non-null  object
#  7   country       7422 non-null   object
#  8   release_year  15981 non-null  object
#  9   duration      15537 non-null  object
#  10  listed_in     15981 non-null  object
#  11  description   15978 non-null  object
#  12  description_  15978 non-null  object
#  13  all           15981 non-null  object
#  14  sentiment     15981 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 1.8+ MB

# %%
movies.to_csv('movies_final.csv')

# %% [markdown]
# ###TV-Shows

# %%
tv_show = pd.read_csv('/Users/anadeondarza/Desktop/ironhack_data/challenges/Proyecto final/tv_show_final.csv')

# %%
tv_show.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6261 entries, 0 to 6260
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  6261 non-null   int64
#  1   Unnamed: 0    6261 non-null   int64
#  2   show_id       6261 non-null   object
#  3   type          6261 non-null   object
#  4   title         6261 non-null   object
#  5   director      227 non-null    object
#  6   cast          3965 non-null   object
#  7   country       3426 non-null   object
#  8   release_year  6261 non-null   int64
#  9   duration      6261 non-null   object
#  10  listed_in     6261 non-null   object
#  11  description   6260 non-null   object
#  12  all           6261 non-null   object
#  13  description_  6260 non-null   object
#  14  sentiment     6261 non-null   object
# dtypes: int64(3), object(12)
# memory usage: 733.8+ KB

# %%
tv_show['release_year'] = tv_show['release_year'].values.astype(str)

# %%
tv_show.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6261 entries, 0 to 6260
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  6261 non-null   int64
#  1   Unnamed: 0    6261 non-null   int64
#  2   show_id       6261 non-null   object
#  3   type          6261 non-null   object
#  4   title         6261 non-null   object
#  5   director      227 non-null    object
#  6   cast          3965 non-null   object
#  7   country       3426 non-null   object
#  8   release_year  6261 non-null   object
#  9   duration      6261 non-null   object
#  10  listed_in     6261 non-null   object
#  11  description   6260 non-null   object
#  12  all           6261 non-null   object
#  13  description_  6260 non-null   object
#  14  sentiment     6261 non-null   object
# dtypes: int64(2), object(13)
# memory usage: 733.8+ KB

# %%
tv_show.to_csv('tv_final.csv')
